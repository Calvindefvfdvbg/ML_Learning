# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, accuracy_score

# %%
# load data set
df = pd.read_csv("Practice.csv")
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print("Summary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
x = df.drop(['Name','Ticket','Cabin','Embarked','Age'], axis = 1)
y = df['Name']
x.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
x.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %%
x.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex             object
# SibSp            int64
# Parch            int64
# Fare           float64
# dtype: object

# %%
# select relevant features
features = ['PassengerId','SibSp','Fare']
x = df[features]
y = df['Survived']

# %%
# encode categorial values
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])
print(df['Sex'])
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int32

# %%
# split the data traing and data and test data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 50)
# scale the features
scaler = StandardScaler()
x_train[['PassengerId','Fare']] = scaler.fit_transform(x_train[['PassengerId','Fare']])
x_test[['PassengerId','Fare']] = scaler.transform(x_test[['PassengerId','Fare']])

# %%
# intialize the gradient Boosting classifier
gbc = GradientBoostingClassifier(n_estimators = 100, learning_rate = 0.1, max_depth =3, random_state = 42)
# train the model
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred = gbc.predict(x_test)
# evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=['Not Survived', 'Survived']))
# Out:
# Accuracy: 0.6567164179104478
#               precision    recall  f1-score   support
#
# Not Survived       0.67      0.85      0.75       162
#     Survived       0.61      0.36      0.45       106
#
#     accuracy                           0.66       268
#    macro avg       0.64      0.61      0.60       268
# weighted avg       0.65      0.66      0.63       268
